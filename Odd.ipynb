# %%
# !s3# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /bin/bash: s3#: command not found
# /kaggle/input/fitness-tracker-dataset/gym_members_exercise_tracking_synthetic_data.csv

# %%
df=pd.read_csv("/kaggle/input/fitness-tracker-dataset/gym_members_exercise_tracking_synthetic_data.csv")
df.head()
# Out:
#     Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0  Female         86.7        1.86     174    152.0         74.0
# 1  26.0  Female         84.7        1.83     166    156.0         73.0
# 2  22.0    Male         64.8        1.85     187    166.0         64.0
# 3  54.0  Female         75.3        1.82     187    169.0         58.0
# 4  34.0  Female         52.8        1.74     177    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0     Strength            12.8
# 1                      1.00            833.0     Strength            27.9
# 2                      1.24           1678.0       Cardio            28.7
# 3                      1.45            628.0       Cardio            31.8
# 4                      1.60           1286.0     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#      BMI
# 0  14.31
# 1  33.49
# 2  12.73
# 3  20.37
# 4  20.83

# %%
import numpy as np

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/kaggle/input/fitness-tracker-dataset/gym_members_exercise_tracking_synthetic_data.csv")
print(df.head())
# Out:
#     Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0  Female         86.7        1.86     174    152.0         74.0
# 1  26.0  Female         84.7        1.83     166    156.0         73.0
# 2  22.0    Male         64.8        1.85     187    166.0         64.0
# 3  54.0  Female         75.3        1.82     187    169.0         58.0
# 4  34.0  Female         52.8        1.74     177    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0     Strength            12.8
# 1                      1.00            833.0     Strength            27.9
# 2                      1.24           1678.0       Cardio            28.7
# 3                      1.45            628.0       Cardio            31.8
# 4                      1.60           1286.0     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#      BMI
# 0  14.31
# 1  33.49
# 2  12.73
# 3  20.37
# 4  20.83

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/fitness-tracker-dataset/gym_members_exercise_tracking_synthetic_data.csv")
print("Shape of the dataset:", df.shape)
print("Columns in the dataset:", df.columns)
print("Dataset info:")
df.info()
print("Summary of numeric columns:")
print(df.describe())
# Out:
# Shape of the dataset: (1800, 15)
# Columns in the dataset: Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   object
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1779 non-null   object
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   object
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
#  12  Workout_Frequency (days/week)  1742 non-null   float64
#  13  Experience_Level               1743 non-null   float64
#  14  BMI                            1770 non-null   float64
# dtypes: float64(12), object(3)
# memory usage: 211.1+ KB
# Summary of numeric columns:
#                Age  Weight (kg)   Height (m)      Avg_BPM  Resting_BPM  \
# count  1790.000000  1778.000000  1774.000000  1770.000000  1781.000000
# mean     34.475419    67.606637     1.739233   146.259322    63.951151
# std      12.315728    19.861408     0.123892    15.219516     7.936502
# min      18.000000    40.000000     1.500000   120.000000    50.000000
# 25%      23.000000    52.300000     1.650000   133.250000    57.000000
# 50%      33.000000    65.300000     1.730000   146.000000    65.000000
# 75%      45.000000    80.100000     1.820000   160.000000    72.000000
# max      59.000000   129.900000     2.000000   169.000000    74.000000
#
#        Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count               1777.000000      1777.000000     1784.000000
# mean                   1.391598      1033.698931       23.509361
# std                    0.372342       328.049662        5.865557
# min                    0.500000       303.000000       10.000000
# 25%                    1.130000       794.000000       20.500000
# 50%                    1.370000      1030.000000       24.300000
# 75%                    1.640000      1249.000000       27.500000
# max                    2.000000      1783.000000       35.000000
#
#        Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# count            1776.000000                    1742.000000       1743.000000
# mean                2.706644                       3.339265          1.823867
# std                 0.710224                       0.947955          0.746568
# min                 1.500000                       2.000000          1.000000
# 25%                 2.100000                       3.000000          1.000000
# 50%                 2.800000                       3.000000          2.000000
# 75%                 3.400000                       4.000000          2.000000
# max                 3.700000                       5.000000          3.000000
#
#                BMI
# count  1770.000000
# mean     19.957774
# std       6.573175
# min      12.320000
# 25%      14.780000
# 50%      18.690000
# 75%      23.517500
# max      49.840000

# %%
df.describe()
# Out:
#                Age  Weight (kg)   Height (m)      Avg_BPM  Resting_BPM  \
# count  1790.000000  1778.000000  1774.000000  1770.000000  1781.000000
# mean     34.475419    67.606637     1.739233   146.259322    63.951151
# std      12.315728    19.861408     0.123892    15.219516     7.936502
# min      18.000000    40.000000     1.500000   120.000000    50.000000
# 25%      23.000000    52.300000     1.650000   133.250000    57.000000
# 50%      33.000000    65.300000     1.730000   146.000000    65.000000
# 75%      45.000000    80.100000     1.820000   160.000000    72.000000
# max      59.000000   129.900000     2.000000   169.000000    74.000000
#
#        Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count               1777.000000      1777.000000     1784.000000
# mean                   1.391598      1033.698931       23.509361
# std                    0.372342       328.049662        5.865557
# min                    0.500000       303.000000       10.000000
# 25%                    1.130000       794.000000       20.500000
# 50%                    1.370000      1030.000000       24.300000
# 75%                    1.640000      1249.000000       27.500000
# max                    2.000000      1783.000000       35.000000
#
#        Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# count            1776.000000                    1742.000000       1743.000000
# mean                2.706644                       3.339265          1.823867
# std                 0.710224                       0.947955          0.746568
# min                 1.500000                       2.000000          1.000000
# 25%                 2.100000                       3.000000          1.000000
# 50%                 2.800000                       3.000000          2.000000
# 75%                 3.400000                       4.000000          2.000000
# max                 3.700000                       5.000000          3.000000
#
#                BMI
# count  1770.000000
# mean     19.957774
# std       6.573175
# min      12.320000
# 25%      14.780000
# 50%      18.690000
# 75%      23.517500
# max      49.840000

# %%
df.isnull().sum()
# Out:
# Age                              10
# Gender                           71
# Weight (kg)                      22
# Height (m)                       26
# Max_BPM                          21
# Avg_BPM                          30
# Resting_BPM                      19
# Session_Duration (hours)         23
# Calories_Burned                  23
# Workout_Type                     61
# Fat_Percentage                   16
# Water_Intake (liters)            24
# Workout_Frequency (days/week)    58
# Experience_Level                 57
# BMI                              30
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Data Heatmap")
plt.show()

# %%
numeric_columns = [
    "Age", "Weight (kg)", "Height (m)", "Max_BPM",
    "Avg_BPM", "Resting_BPM", "Session_Duration (hours)",
    "Calories_Burned", "Fat_Percentage", "Water_Intake (liters)",
    "BMI"
]

for col in numeric_columns:
    data[col] = data[col].fillna(data[col].mean())

# %%
categorical_columns = ["Gender", "Workout_Type", "Workout_Frequency (days/week)", "Experience_Level"]

for col in categorical_columns:
    if data[col].notna().any():  # Check if there are any non-NaN values
        mode_value = data[col].mode()
        if not mode_value.empty:  # Ensure mode() is not empty
            data[col] = data[col].fillna(mode_value[0])
    else:
        # Handle cases where the column is entirely NaN (if needed)
        print(f"Column '{col}' is entirely NaN and cannot be imputed.")
# Out:
# Column 'Gender' is entirely NaN and cannot be imputed.
# Column 'Workout_Type' is entirely NaN and cannot be imputed.
# Column 'Workout_Frequency (days/week)' is entirely NaN and cannot be imputed.
# Column 'Experience_Level' is entirely NaN and cannot be imputed.

# %%
if data[col].notna().any():
    mode_value = data[col].mode()
    if not mode_value.empty:
        data[col] = data[col].fillna(mode_value[0])
else:
    data[col] = "Unknown"  # Replace with a default value

# %%
print(f"Mode of column '{col}':", data[col].mode())
# Out:
# Mode of column 'Experience_Level': Series([], Name: Experience_Level, dtype: object)

# %%
print(data.isnull().sum())
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# Calculated_BMI                   0
# Workout_Intensity                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0     34.0  Female         86.7        1.86     174    152.0         74.0
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 4     34.0  Female         52.8        1.74     177    169.0         66.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1795  54.0    Male         88.5        2.00     173    134.0         58.0
# 1796  52.0    Male         84.3        1.69     164    169.0         54.0
# 1797  47.0    Male         70.1        1.84     188    129.0         67.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
# 1799  40.0    Male         79.5        1.92     184    156.0         52.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                         1.12            712.0     Strength            12.8
# 1                         1.00            833.0     Strength            27.9
# 2                         1.24           1678.0       Cardio            28.7
# 3                         1.45            628.0       Cardio            31.8
# 4                         1.60           1286.0     Strength            26.4
# ...                        ...              ...          ...             ...
# 1795                      1.11           1388.0         HIIT            27.7
# 1796                      0.77           1367.0         HIIT            32.6
# 1797                      1.20           1261.0     Strength            28.4
# 1798                      1.04            956.0       Cardio            32.9
# 1799                      1.29           1178.0     Strength            14.7
#
#       Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                       2.4                            5.0               2.0
# 1                       2.8                            5.0               2.0
# 2                       1.9                            3.0               2.0
# 3                       2.4                            4.0               1.0
# 4                       3.2                            4.0               2.0
# ...                     ...                            ...               ...
# 1795                    3.7                            3.0               2.0
# 1796                    2.9                            3.0               2.0
# 1797                    2.5                            3.0               2.0
# 1798                    1.7                            4.0               3.0
# 1799                    1.5                            4.0               1.0
#
#         BMI
# 0     14.31
# 1     33.49
# 2     12.73
# 3     20.37
# 4     20.83
# ...     ...
# 1795  36.73
# 1796  15.11
# 1797  17.99
# 1798  12.65
# 1799  23.51
#
# [1800 rows x 15 columns]

# %%
invalid_entries = df['Max_BPM'].apply(pd.to_numeric, errors='coerce').isna().sum()
print(f"Number of invalid entries in 'Max_BPM': {invalid_entries}")
# Out:
# Number of invalid entries in 'Max_BPM': 28

# %%
df['Max_BPM'] = pd.to_numeric(df['Max_BPM'], errors='coerce')
nan_count = df['Max_BPM'].isna().sum()
print(f"Number of NaN values in 'Max_BPM' after conversion: {nan_count}")
# Out:
# Number of NaN values in 'Max_BPM' after conversion: 28

# %%
df['Max_BPM'] = df['Max_BPM'].fillna(df['Max_BPM'].median())
print(f"Number of NaN values in 'Max_BPM' after imputation: {df['Max_BPM'].isna().sum()}")
# Out:
# Number of NaN values in 'Max_BPM' after imputation: 0

# %%
gender_unique = df['Gender'].unique()
print(f"Unique values in 'Gender' column: {gender_unique}")
workout_type_unique = df['Workout_Type'].unique()
print(f"Unique values in 'Workout_Type' column: {workout_type_unique}")
# Out:
# Unique values in 'Gender' column: ['Female' 'Male' nan]
# Unique values in 'Workout_Type' column: ['Strength' 'Cardio' 'HIIT' 'Yoga' nan '\\nStrength' '\\tCardio' '\\tYoga']

# %%
df['Gender'] = df['Gender'].replace({'M': 'Male', 'm': 'Male', 'F': 'Female', 'f': 'Female'})
print(f"Unique values in 'Gender' after standardization: {df['Gender'].unique()}")
# Out:
# Unique values in 'Gender' after standardization: ['Female' 'Male' nan]

# %%
df['Workout_Type'] = df['Workout_Type'].replace({'Yoga': 'Yoga', 'Running': 'Running', 'Swimming': 'Swimming'})
print(f"Unique values in 'Workout_Type' after standardization: {df['Workout_Type'].unique()}")
# Out:
# Unique values in 'Workout_Type' after standardization: ['Strength' 'Cardio' 'HIIT' 'Yoga' nan '\\nStrength' '\\tCardio' '\\tYoga']

# %%
import pandas as pd
df['Calculated_BMI'] = df['Weight (kg)'] / (df['Height (m)'] ** 2)
inconsistent_bmi = (df['BMI'] != df['Calculated_BMI'])
print(f"Number of inconsistencies in BMI: {inconsistent_bmi.sum()}")
df.loc[inconsistent_bmi, 'BMI'] = df.loc[inconsistent_bmi, 'Calculated_BMI']
print(f"Number of NaN values in 'BMI' after recalculation: {df['BMI'].isna().sum()}")
df['Workout_Intensity'] = df['Avg_BPM'] / df['Max_BPM']
print(df[['Avg_BPM', 'Max_BPM', 'Workout_Intensity']].head())
# Out:
# Number of inconsistencies in BMI: 1800
# Number of NaN values in 'BMI' after recalculation: 47
#    Avg_BPM  Max_BPM  Workout_Intensity
# 0    152.0    174.0           0.873563
# 1    156.0    166.0           0.939759
# 2    166.0    187.0           0.887701
# 3    169.0    187.0           0.903743
# 4    169.0    177.0           0.954802

# %%
import matplotlib.pyplot as plt
import seaborn as sns
numeric_columns = ['Age', 'Calories_Burned', 'BMI', 'Avg_BPM', 'Max_BPM']

plt.figure(figsize=(12, 8))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 3, i)  # Arrange plots in a grid
    sns.histplot(df[col], kde=True, bins=20)  # kde=True adds a density plot
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()  
plt.show()
outlier_columns = ['Age', 'BMI', 'Calories_Burned']

plt.figure(figsize=(12, 6))
for i, col in enumerate(outlier_columns, 1):
    plt.subplot(1, 3, i)  # Arrange plots in a grid
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()
categorical_columns = ['Gender', 'Workout_Type']

plt.figure(figsize=(12, 6))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(1, 2, i)  # Arrange plots in a grid
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import numpy as np
def detect_outliers(df, columns):
    outliers = {}
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers
numeric_columns = ['Age', 'BMI', 'Calories_Burned', 'Avg_BPM', 'Max_BPM']
outliers = detect_outliers(df, numeric_columns)
for col, data in outliers.items():
    print(f"Outliers in {col}:")
    print(data)
    print("\n")
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
print(df.head())
# Out:
# Outliers in Age:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in BMI:
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 20    26.0    Male        129.9        1.71    196.0    136.0         74.0
# 21    22.0  Female        102.4        1.50    173.0    156.0         55.0
# 23    18.0    Male        129.4        1.50    177.0    145.0         71.0
# 33    20.0  Female        103.4        1.53    180.0    166.0         56.0
# 42    23.0    Male        107.6        1.50    181.0    136.0         71.0
# 129   31.0  Female        129.9        1.70    190.0    169.0         69.0
# 266   33.0  Female        129.9        1.69    168.0    152.0         74.0
# 378   19.0  Female        129.9        1.71    161.0    169.0         56.0
# 422   47.0    Male        121.4        1.61    164.0    155.0         74.0
# 500   35.0  Female        127.6        1.65    174.0    156.0         56.0
# 573   37.0    Male        108.7        1.55    163.0    122.0         68.0
# 592   33.0  Female        129.9        1.56    189.0    138.0         73.0
# 715   38.0    Male        101.8        1.51    163.0    169.0         72.0
# 820   50.0  Female        103.8        1.54    185.0    169.0         56.0
# 863   45.0    Male        121.2        1.67    186.0    133.0         55.0
# 1005  22.0    Male        129.9        1.62    185.0    141.0         52.0
# 1007  44.0  Female        115.6        1.50    186.0    145.0         55.0
# 1112  28.0  Female        109.4        1.58    170.0    165.0         74.0
# 1129  28.0  Female        101.9        1.50    196.0    164.0         56.0
# 1164  55.0    Male        104.9        1.56    187.0    155.0         58.0
# 1165  34.0  Female        102.1        1.53    178.0    152.0         50.0
# 1247  23.0    Male        114.9        1.61    180.0    120.0         56.0
# 1255  38.0  Female         99.1        1.50    185.0    159.0         74.0
# 1437  59.0    Male        108.3        1.53    183.0    122.0         50.0
# 1468  18.0    Male        123.8        1.62    164.0    167.0         59.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 20                        1.27            931.0         Yoga            26.6
# 21                        1.44            453.0         HIIT            17.5
# 23                         NaN            772.0     Strength            22.0
# 33                        1.28            631.0         HIIT            23.0
# 42                        1.53           1062.0       Cardio            10.0
# 129                       1.38            735.0     Strength            10.0
# 266                       1.61            810.0     Strength            27.5
# 378                       2.00            443.0         Yoga            29.6
# 422                       0.94            934.0     Strength            24.7
# 500                       1.90           1084.0         HIIT            20.4
# 573                       1.19           1104.0     Strength            26.9
# 592                       2.00            993.0     Strength            34.0
# 715                       1.42           1384.0     Strength            25.6
# 820                       2.00            766.0         HIIT            27.3
# 863                       2.00            466.0       Cardio            16.7
# 1005                      1.62            571.0     Strength            27.2
# 1007                      1.65           1075.0         HIIT            25.1
# 1112                      1.94            619.0         HIIT            21.9
# 1129                      1.87           1211.0     \tCardio            23.8
# 1164                      0.87           1260.0   \nStrength            27.8
# 1165                      2.00           1783.0     Strength            26.5
# 1247                      1.27            891.0         HIIT            28.0
# 1255                      1.38            995.0         HIIT            17.8
# 1437                      0.86           1071.0         HIIT            21.9
# 1468                      1.43            303.0     Strength            22.3
#
#       Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 20                      1.8                            5.0               1.0
# 21                      1.6                            4.0               3.0
# 23                      1.7                            5.0               1.0
# 33                      3.0                            4.0               1.0
# 42                      2.3                            5.0               3.0
# 129                     2.1                            3.0               3.0
# 266                     3.5                            NaN               2.0
# 378                     2.4                            4.0               2.0
# 422                     2.5                            2.0               1.0
# 500                     3.4                            5.0               1.0
# 573                     1.6                            4.0               2.0
# 592                     2.3                            3.0               2.0
# 715                     3.3                            4.0               1.0
# 820                     3.1                            3.0               1.0
# 863                     3.4                            4.0               1.0
# 1005                    1.8                            4.0               2.0
# 1007                    3.5                            2.0               1.0
# 1112                    2.2                            5.0               1.0
# 1129                    3.2                            2.0               2.0
# 1164                    3.5                            3.0               1.0
# 1165                    2.1                            3.0               1.0
# 1247                    3.3                            3.0               1.0
# 1255                    1.5                            4.0               1.0
# 1437                    3.3                            3.0               1.0
# 1468                    3.6                            2.0               3.0
#
#             BMI  Calculated_BMI  Workout_Intensity
# 20    44.423925       44.423925           0.693878
# 21    45.511111       45.511111           0.901734
# 23    57.511111       57.511111           0.819209
# 33    44.171045       44.171045           0.922222
# 42    47.822222       47.822222           0.751381
# 129   44.948097       44.948097           0.889474
# 266   45.481601       45.481601           0.904762
# 378   44.423925       44.423925           1.049689
# 422   46.834613       46.834613           0.945122
# 500   46.868687       46.868687           0.896552
# 573   45.244537       45.244537           0.748466
# 592   53.377712       53.377712           0.730159
# 715   44.647165       44.647165           1.036810
# 820   43.767920       43.767920           0.913514
# 863   43.457994       43.457994           0.715054
# 1005  49.497028       49.497028           0.762162
# 1007  51.377778       51.377778           0.779570
# 1112  43.823105       43.823105           0.970588
# 1129  45.288889       45.288889           0.836735
# 1164  43.104865       43.104865           0.828877
# 1165  43.615703       43.615703           0.853933
# 1247  44.326994       44.326994           0.666667
# 1255  44.044444       44.044444           0.859459
# 1437  46.264257       46.264257           0.666667
# 1468  47.172687       47.172687           1.018293
#
#
# Outliers in Calories_Burned:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in Avg_BPM:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in Max_BPM:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
#     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0  Female         86.7        1.86    174.0    152.0         74.0
# 1  26.0  Female         84.7        1.83    166.0    156.0         73.0
# 2  22.0    Male         64.8        1.85    187.0    166.0         64.0
# 3  54.0  Female         75.3        1.82    187.0    169.0         58.0
# 4  34.0  Female         52.8        1.74    177.0    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0     Strength            12.8
# 1                      1.00            833.0     Strength            27.9
# 2                      1.24           1678.0       Cardio            28.7
# 3                      1.45            628.0       Cardio            31.8
# 4                      1.60           1286.0     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#          BMI  Calculated_BMI  Workout_Intensity
# 0  25.060701       25.060701           0.873563
# 1  25.291887       25.291887           0.939759
# 2  18.933528       18.933528           0.887701
# 3  22.732762       22.732762           0.903743
# 4  17.439556       17.439556           0.954802

# %%
import pandas as pd
numeric_columns = ['Age', 'BMI', 'Calories_Burned', 'Avg_BPM', 'Max_BPM']
def detect_outliers(df, columns):
    outliers = {}
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Detect outliers
        outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers
outliers = detect_outliers(df, numeric_columns)
for col, data in outliers.items():
    print(f"Outliers in {col}:")
    print(data)
    print("\n")
# Out:
# Outliers in Age:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in BMI:
#        Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 188   23.0  Female         95.6        1.50    196.0    152.0         56.0
# 279   45.0    Male        129.9        1.75    197.0    154.0         73.0
# 320   41.0  Female        117.7        1.67    189.0    123.0         58.0
# 972   49.0    Male        110.8        1.62    162.0    169.0         59.0
# 1154  48.0  Female        122.3        1.71    183.0    120.0         63.0
# 1699  18.0  Female        129.9        1.76    168.0    135.0         50.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 188                       0.50            639.0         Yoga            25.2
# 279                       1.97            757.0       Cardio            23.5
# 320                       2.00           1243.0         Yoga            26.2
# 972                       1.34           1783.0       Cardio            11.5
# 1154                      0.79            992.0          NaN            10.0
# 1699                      1.30           1208.0         HIIT            25.1
#
#       Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 188                     3.2                            2.0               1.0
# 279                     2.4                            5.0               1.0
# 320                     3.2                            2.0               1.0
# 972                     1.7                            4.0               2.0
# 1154                    2.6                            4.0               1.0
# 1699                    2.0                            3.0               2.0
#
#             BMI  Calculated_BMI  Workout_Intensity
# 188   42.488889       42.488889           0.775510
# 279   42.416327       42.416327           0.781726
# 320   42.203019       42.203019           0.650794
# 972   42.219174       42.219174           1.043210
# 1154  41.824835       41.824835           0.655738
# 1699  41.935692       41.935692           0.803571
#
#
# Outliers in Calories_Burned:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in Avg_BPM:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []
#
#
# Outliers in Max_BPM:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI, Calculated_BMI, Workout_Intensity]
# Index: []

# %%
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
print(df.head())
# Out:
#     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0  Female         86.7        1.86    174.0    152.0         74.0
# 1  26.0  Female         84.7        1.83    166.0    156.0         73.0
# 2  22.0    Male         64.8        1.85    187.0    166.0         64.0
# 3  54.0  Female         75.3        1.82    187.0    169.0         58.0
# 4  34.0  Female         52.8        1.74    177.0    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0     Strength            12.8
# 1                      1.00            833.0     Strength            27.9
# 2                      1.24           1678.0       Cardio            28.7
# 3                      1.45            628.0       Cardio            31.8
# 4                      1.60           1286.0     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#          BMI  Calculated_BMI  Workout_Intensity
# 0  25.060701       25.060701           0.873563
# 1  25.291887       25.291887           0.939759
# 2  18.933528       18.933528           0.887701
# 3  22.732762       22.732762           0.903743
# 4  17.439556       17.439556           0.954802

# %%
for col in numeric_columns:
    df[col] = df[col].apply(lambda x: np.log(x + 1) if x > 0 else 0)
print(df.head())
# Out:
#         Age  Gender  Weight (kg)  Height (m)   Max_BPM   Avg_BPM  Resting_BPM  \
# 0  3.555348  Female         86.7        1.86  5.164786  5.030438         74.0
# 1  3.295837  Female         84.7        1.83  5.117994  5.056246         73.0
# 2  3.135494    Male         64.8        1.85  5.236442  5.117994         64.0
# 3  4.007333  Female         75.3        1.82  5.236442  5.135798         58.0
# 4  3.555348  Female         52.8        1.74  5.181784  5.135798         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12         6.569481     Strength            12.8
# 1                      1.00         6.726233     Strength            27.9
# 2                      1.24         7.425954       Cardio            28.7
# 3                      1.45         6.444131       Cardio            31.8
# 4                      1.60         7.160069     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#         BMI  Calculated_BMI  Workout_Intensity
# 0  3.260428       25.060701           0.873563
# 1  3.269260       25.291887           0.939759
# 2  2.992403       18.933528           0.887701
# 3  3.166856       22.732762           0.903743
# 4  2.914498       17.439556           0.954802

# %%
for col in numeric_columns:
    lower_percentile = df[col].quantile(0.01)
    upper_percentile = df[col].quantile(0.99)
    df[col] = df[col].clip(lower=lower_percentile, upper=upper_percentile)
print(df.head())
# Out:
#         Age  Gender  Weight (kg)  Height (m)   Max_BPM   Avg_BPM  Resting_BPM  \
# 0  3.555348  Female         86.7        1.86  5.164786  5.030438         74.0
# 1  3.295837  Female         84.7        1.83  5.117994  5.056246         73.0
# 2  3.135494    Male         64.8        1.85  5.236442  5.117994         64.0
# 3  4.007333  Female         75.3        1.82  5.236442  5.135798         58.0
# 4  3.555348  Female         52.8        1.74  5.181784  5.135798         66.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12         6.569481     Strength            12.8
# 1                      1.00         6.726233     Strength            27.9
# 2                      1.24         7.425954       Cardio            28.7
# 3                      1.45         6.444131       Cardio            31.8
# 4                      1.60         7.160069     Strength            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#         BMI  Calculated_BMI  Workout_Intensity
# 0  3.260428       25.060701           0.873563
# 1  3.269260       25.291887           0.939759
# 2  2.992403       18.933528           0.887701
# 3  3.166856       22.732762           0.903743
# 4  2.914498       17.439556           0.954802

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Heatmap of Numeric Columns")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /opt/conda/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x="Workout_Type", y="Calories_Burned", errorbar=None, palette="viridis")
plt.title("Calories Burned by Workout Type")
plt.xlabel("Workout Type")
plt.ylabel("Calories Burned")
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x="Gender", y="BMI", palette="pastel")
plt.title("BMI Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("BMI")
plt.show()

# %%
sns.pairplot(data, vars=["BMI", "Calories_Burned", "Workout_Frequency (days/week)"], hue="Gender", palette="Set2")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd
data_encoded = pd.get_dummies(data, columns=['Gender', 'Workout_Type'], drop_first=True)
print(data_encoded.head())
# Out:
#     Age  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0         86.7        1.86     174    152.0         74.0
# 1  26.0         84.7        1.83     166    156.0         73.0
# 2  22.0         64.8        1.85     187    166.0         64.0
# 3  54.0         75.3        1.82     187    169.0         58.0
# 4  34.0         52.8        1.74     177    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# 0                      1.12            712.0            12.8
# 1                      1.00            833.0            27.9
# 2                      1.24           1678.0            28.7
# 3                      1.45            628.0            31.8
# 4                      1.60           1286.0            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#      BMI  Gender_Male  Workout_Type_HIIT  Workout_Type_Strength  \
# 0  14.31        False              False                   True
# 1  33.49        False              False                   True
# 2  12.73         True              False                  False
# 3  20.37        False              False                  False
# 4  20.83        False              False                   True
#
#    Workout_Type_Yoga  Workout_Type_\nStrength  Workout_Type_\tCardio  \
# 0              False                    False                  False
# 1              False                    False                  False
# 2              False                    False                  False
# 3              False                    False                  False
# 4              False                    False                  False
#
#    Workout_Type_\tYoga
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['Gender'] = label_encoder.fit_transform(data['Gender'])
data['Workout_Type'] = label_encoder.fit_transform(data['Workout_Type'])

# Check the encoded data
print(data.head())
# Out:
#     Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.0       0         86.7        1.86     174    152.0         74.0
# 1  26.0       0         84.7        1.83     166    156.0         73.0
# 2  22.0       1         64.8        1.85     187    166.0         64.0
# 3  54.0       0         75.3        1.82     187    169.0         58.0
# 4  34.0       0         52.8        1.74     177    169.0         66.0
#
#    Session_Duration (hours)  Calories_Burned  Workout_Type  Fat_Percentage  \
# 0                      1.12            712.0             2            12.8
# 1                      1.00            833.0             2            27.9
# 2                      1.24           1678.0             0            28.7
# 3                      1.45            628.0             0            31.8
# 4                      1.60           1286.0             2            26.4
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    2.4                            5.0               2.0
# 1                    2.8                            5.0               2.0
# 2                    1.9                            3.0               2.0
# 3                    2.4                            4.0               1.0
# 4                    3.2                            4.0               2.0
#
#      BMI
# 0  14.31
# 1  33.49
# 2  12.73
# 3  20.37
# 4  20.83

# %%
data['Calculated_BMI'] = data['Weight (kg)'] / (data['Height (m)'] ** 2)

# %%
print(data['Max_BPM'].unique())
data['Max_BPM'] = pd.to_numeric(data['Max_BPM'], errors='coerce')
data['Workout_Intensity'] = data['Max_BPM'] - data['Resting_BPM']
print(data[['Max_BPM', 'Resting_BPM', 'Workout_Intensity']].head())
# Out:
# [174. 166. 187. 177. 161. 191. 181. 195. 168. 186. 176. 197. 171. 184.
#  196. 173. 192. 165. 188. 183. 189. 193. 198. 199. 180. 178.  nan 160.
#  194. 185. 167. 169. 172. 182. 164. 175. 163. 170. 190. 162. 179.]
#    Max_BPM  Resting_BPM  Workout_Intensity
# 0    174.0         74.0              100.0
# 1    166.0         73.0               93.0
# 2    187.0         64.0              123.0
# 3    187.0         58.0              129.0
# 4    177.0         66.0              111.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[numeric_columns] = scaler.fit_transform(data[numeric_columns])
print(data[numeric_columns].head())
# Out:
#    Calories_Burned  Session_Duration (hours)       BMI   Max_BPM   Avg_BPM  \
# 0         0.276351                  0.413333  0.053038  0.358974  0.653061
# 1         0.358108                  0.333333  0.564232  0.153846  0.734694
# 2         0.929054                  0.493333  0.010928  0.692308  0.938776
# 3         0.219595                  0.633333  0.214552  0.692308  1.000000
# 4         0.664189                  0.733333  0.226812  0.435897  1.000000
#
#    Resting_BPM  Fat_Percentage  Water_Intake (liters)  \
# 0     1.000000           0.112               0.409091
# 1     0.958333           0.716               0.590909
# 2     0.583333           0.748               0.181818
# 3     0.333333           0.872               0.409091
# 4     0.666667           0.656               0.772727
#
#    Workout_Frequency (days/week)  Experience_Level
# 0                       1.000000               0.5
# 1                       1.000000               0.5
# 2                       0.333333               0.5
# 3                       0.666667               0.0
# 4                       0.666667               0.5

# %%
calories_by_workout_gender = data.groupby(['Workout_Type', 'Gender'])['Calories_Burned'].mean().reset_index()
print(calories_by_workout_gender)
# Out:
#     Workout_Type  Gender  Calories_Burned
# 0              0       0         0.486622
# 1              0       1         0.515389
# 2              0       2         0.479784
# 3              1       0         0.473507
# 4              1       1         0.479149
# 5              1       2         0.416959
# 6              2       0         0.477959
# 7              2       1         0.489982
# 8              2       2         0.475000
# 9              3       0         0.494633
# 10             3       1         0.539889
# 11             3       2         0.500416
# 12             4       0         0.386486
# 13             4       1         0.490203
# 14             4       2         0.279054
# 15             5       0         0.565270
# 16             5       1         0.570045
# 17             6       0         0.528475
# 18             6       1         0.595721
# 19             7       0         0.464599
# 20             7       1         0.469136
# 21             7       2         0.604223

# %%
correlation = data['Session_Duration (hours)'].corr(data['Calories_Burned'])
print(f"Correlation between Session Duration and Calories Burned: {correlation}")
# Out:
# Correlation between Session Duration and Calories Burned: 0.028630981663187356

# %%
bmi_by_frequency = data.groupby('Workout_Frequency (days/week)')['BMI'].mean().reset_index()
print(bmi_by_frequency)
# Out:
#    Workout_Frequency (days/week)       BMI
# 0                       0.000000  0.197404
# 1                       0.333333  0.212149
# 2                       0.666667  0.200640
# 3                       1.000000  0.203958
